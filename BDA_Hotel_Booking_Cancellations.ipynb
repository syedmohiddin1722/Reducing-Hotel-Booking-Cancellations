# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhanusri08/Hotel-Booking-Cancellation-Analysis/blob/main/BDA_Hotel_Booking_Cancellations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Loading the dataset**

# %%
df=pd.read_csv('/content/synthetic_hotel_data.csv')

# %% [markdown]
# # **Exploratory Data Analysis and Data Cleaning**

# %%
df.head()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 0  Trupthi Resort            0         16               2022
# 1  Trupthi Resort            1        130               2022
# 2     Hotel Grand            0         74               2023
# 3     Hotel Grand            0         91               2024
# 4     Hotel Grand            0          2               2023
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        31                         31
# 1             August                        31                          1
# 2           December                        53                         27
# 3              April                        16                         20
# 4               July                        28                          8
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
df.tail(10)
# Out:
#                  hotel  is_canceled  lead_time  arrival_date_year  \
# 999990  Trupthi Resort            0         31               2022
# 999991     Hotel Grand            1        274               2023
# 999992     Hotel Grand            0         24               2023
# 999993     Hotel Grand            1         37               2022
# 999994     Hotel Grand            1         75               2023
# 999995  Trupthi Resort            1         64               2022
# 999996     Hotel Grand            0         62               2023
# 999997     Hotel Grand            1         65               2022
# 999998  Trupthi Resort            0          6               2022
# 999999  Trupthi Resort            0          1               2022
#
#        arrival_date_month  arrival_date_week_number  \
# 999990               July                        29
# 999991               July                        29
# 999992                May                        19
# ...

# %%
df.shape
# Out:
# (1000000, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   hotel                           1000000 non-null  object
#  1   is_canceled                     1000000 non-null  int64
#  2   lead_time                       1000000 non-null  int64
#  3   arrival_date_year               1000000 non-null  int64
#  4   arrival_date_month              1000000 non-null  object
#  5   arrival_date_week_number        1000000 non-null  int64
#  6   arrival_date_day_of_month       1000000 non-null  int64
#  7   stays_in_weekend_nights         1000000 non-null  int64
#  8   stays_in_week_nights            1000000 non-null  int64
#  9   adults                          1000000 non-null  int64
#  10  children                        999964 non-null   float64
# ...

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'],format="%d-%m-%Y")

# %%
df.info() #object datatypes means categorical columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   hotel                           1000000 non-null  object
#  1   is_canceled                     1000000 non-null  int64
#  2   lead_time                       1000000 non-null  int64
#  3   arrival_date_year               1000000 non-null  int64
#  4   arrival_date_month              1000000 non-null  object
#  5   arrival_date_week_number        1000000 non-null  int64
#  6   arrival_date_day_of_month       1000000 non-null  int64
#  7   stays_in_weekend_nights         1000000 non-null  int64
#  8   stays_in_week_nights            1000000 non-null  int64
#  9   adults                          1000000 non-null  int64
#  10  children                        999964 non-null   float64
# ...

# %%
df.describe(include='object')
# Out:
#               hotel arrival_date_month     meal  country market_segment  \
# count       1000000            1000000  1000000  1000000        1000000
# unique            2                 12        5        1              8
# top     Hotel Grand                May       BB      IND      Online TA
# freq         660699             147231   773654  1000000         473781
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count               1000000            1000000            1000000
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                 819863             720439             619959
#
#        deposit_type customer_type reservation_status
# count       1000000       1000000            1000000
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         876686        750204             629655

# %%
for col in df.describe(include = 'object').columns:
  print(col)
  print(df[col].unique())
  print('-'*50)
# Out:
# hotel
# ['Trupthi Resort' 'Hotel Grand']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'December' 'April' 'May' 'March' 'June' 'September'
#  'November' 'January' 'October' 'February']
# --------------------------------------------------
# meal
# ['BB' 'HB' 'SC' 'FB' 'Undefined']
# --------------------------------------------------
# country
# ['IND']
# --------------------------------------------------
# market_segment
# ['Direct' 'Online TA' 'Offline TA/TO' 'Corporate' 'Groups' 'Complementary'
#  'Aviation' 'Undefined']
# --------------------------------------------------
# distribution_channel
# ['Direct' 'TA/TO' 'Corporate' 'GDS' 'Undefined']
# --------------------------------------------------
# reserved_room_type
# ['A' 'D' 'B' 'F' 'C' 'E' 'G' 'H' 'P' 'L']
# --------------------------------------------------
# assigned_room_type
# ['A' 'D' 'B' 'E' 'F' 'C' 'G' 'I' 'K' 'H' 'P' 'L']
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                              36
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['company','agent'],axis=1,inplace=True)
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  999964.000000  999964.000000      999964.000000
# mean        0.370322     103.958150        2022.610472
# min         0.000000       0.000000        2022.000000
# 25%         0.000000      18.000000        2022.000000
# 50%         0.000000      69.000000        2022.000000
# 75%         1.000000     160.000000        2023.000000
# max         1.000000     737.000000        2024.000000
# std         0.482891     106.708165           0.706319
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             999964.000000              999964.000000
# mean                  27.183247                  15.803621
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df['adr'].plot(kind='box') #outlier  Visualization
# Out:
# <Axes: >

# %%
df=df[df['adr']<5000]

# %%
df=df[df['lead_time']<120]
df=df[df['adults']<9]
df=df[df['children']<7]
df=df[df['babies']<5]
df=df[df['days_in_waiting_list']<120]
df=df[df['adr']<5000]

# %%
df.describe()#max value of adr is 510,before it is 5400)
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  999955.000000  999955.000000      999955.000000
# mean        0.370317     103.958771        2022.610477
# min         0.000000       0.000000        2022.000000
# 25%         0.000000      18.000000        2022.000000
# 50%         0.000000      69.000000        2022.000000
# 75%         1.000000     160.000000        2023.000000
# max         1.000000     737.000000        2024.000000
# std         0.482890     106.708445           0.706319
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             999955.000000              999955.000000
# mean                  27.183374                  15.803538
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# # **Data Analysis and Visualizations**

# %%
cancelled_percntage=df['is_canceled'].value_counts(normalize=True)
print(cancelled_percntage)
#37.0percentage of people cancelled reservations,62.95 not cancelled the bookings
plt.figure(figsize=(5,4))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
plt.show()
# Out:
# is_canceled
# 0    0.629683
# 1    0.370317
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')

# Adjust the legend position
ax1.legend(bbox_to_anchor=(1, 1))

plt.title('Reservation status in different hotels', size=20)
plt.xlabel('Hotel')
plt.ylabel('Number of reservations')
plt.show()
#Individual hotels cancellation rates.

# %%
Trupthi_Resort=df[df['hotel']=='Trupthi Resort']
Trupthi_Resort['is_canceled'].value_counts(normalize=True)#over 28% of cancellations takes place in trupthi Resort
# Out:
# is_canceled
# 0    0.720039
# 1    0.279961
# Name: proportion, dtype: float64

# %%
Hotel_Grand=df[df['hotel']=='Hotel Grand']
Hotel_Grand['is_canceled'].value_counts(normalize=True)#over 41% of cancellations takes place in trupthi Resort
# Out:
# is_canceled
# 0    0.583278
# 1    0.416722
# Name: proportion, dtype: float64

# %%
Trupthi_Resort=Trupthi_Resort.groupby('reservation_status_date')[['adr']].mean()
Hotel_Grand=Hotel_Grand.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in Hotel Grand and Trupthi Resort',fontsize=30)
plt.plot(Trupthi_Resort.index,Trupthi_Resort['adr'],label='Trupthi_Resort')
plt.plot(Hotel_Grand.index,Hotel_Grand['adr'],label='Hotel_Grand')
plt.legend(fontsize=20)
plt.show()

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='month',hue='is_canceled',data=df)
plt.title('Reservations status per month')
plt.ylabel('number of reservations')
plt.xlabel('month')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 8))
plt.title('ADR per month', fontsize=30)

# Corrected the arguments for sns.barplot
sns.barplot(x='month', y='adr', data=df[df['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())

plt.legend(fontsize=20)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        473765
# Offline TA/TO    202373
# Groups           165781
# Direct           105160
# Corporate         44663
# Complementary      6223
# Aviation           1990
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)#percentage count
#around 47% of them from online TA have high cancellation.
# Out:
# market_segment
# Online TA        0.473786
# Offline TA/TO    0.202382
# Groups           0.165788
# Direct           0.105165
# Corporate        0.044665
# Complementary    0.006223
# Aviation         0.001990
# Name: proportion, dtype: float64

# %%
# Filter the canceled and non-canceled data
cancelled_data = df[df['is_canceled'] == 1]
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data = df[df['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

# Plotting the data
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate', fontsize=20)
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='Not Cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='Cancelled')
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate (ADR)')
plt.legend()
plt.show()

# %%
# Ensure that 'reservation_status_date' is in datetime format
cancelled_df_adr['reservation_status_date'] = pd.to_datetime(cancelled_df_adr['reservation_status_date'])
not_cancelled_df_adr['reservation_status_date'] = pd.to_datetime(not_cancelled_df_adr['reservation_status_date'])

# Filter dataframes based on 'reservation_status_date'
cancelled_df_adr = cancelled_df_adr[cancelled_df_adr['reservation_status_date'] > '2016-01-01']
not_cancelled_df_adr = not_cancelled_df_adr[not_cancelled_df_adr['reservation_status_date'] > '2016-01-01']

# Plotting the Average Daily Rate (ADR)
plt.figure(figsize=(20, 6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='cancelled')
plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='reserved_room_type', hue='is_canceled', data=df, palette='Set2')
plt.title('Cancellation Rate by Reserved Room Type')
plt.xlabel('Reserved Room Type')
plt.ylabel('Count')
plt.show()

plt.figure(figsize=(12, 6))
sns.countplot(x='assigned_room_type', hue='is_canceled', data=df, palette='Set3')
plt.title('Cancellation Rate by Assigned Room Type')
plt.xlabel('Assigned Room Type')
plt.ylabel('Count')
plt.show()

# %%
# Calculate cancellation rate by total_of_special_requests
special_requests_cancellation = df.groupby('total_of_special_requests')['is_canceled'].mean()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=special_requests_cancellation.index, y=special_requests_cancellation.values)
plt.title('Cancellation Rate by Total Special Requests')
plt.xlabel('Total Special Requests')
plt.ylabel('Cancellation Rate')
plt.show()

# %%
deposit_cancellation = df.groupby('deposit_type')['is_canceled'].mean()

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=deposit_cancellation.index, y=deposit_cancellation.values, palette='Set1')
plt.title('Cancellation Rate by Deposit Type')
plt.xlabel('Deposit Type')
plt.ylabel('Cancellation Rate')
plt.show()

# %%
# Calculate total stay duration
df['stay_duration'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

# Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='stay_duration', y='is_canceled', data=df)
plt.title('Cancellation Rate by Stay Duration')
plt.xlabel('Stay Duration (Nights)')
plt.ylabel('Cancellation (0 or 1)')
plt.show()
